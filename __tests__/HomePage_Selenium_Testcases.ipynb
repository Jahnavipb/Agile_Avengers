# %%
#HOME_PAGE
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.alert import Alert

driver = webdriver.Chrome()

# Navigate to the website
driver.get('website URL')

driver.maximize_window()

#Home page
driver.find_element(By.LINK_TEXT, "Home").click()
time.sleep(2)
driver.find_element(By.TAG_NAME,value="body").send_keys(Keys.PAGE_DOWN)
time.sleep(2)
driver.find_element(By.TAG_NAME,value="body").send_keys(Keys.UP)
time.sleep(2)

#Book Demo page
bookdemo = driver.find_element(By.LINK_TEXT, "Book Demo")
time.sleep(2)
driver.execute_script("arguments[0].click()",bookdemo)
time.sleep(2)
driver.find_element(By.ID,"name").send_keys("Sushil")
time.sleep(2)
driver.find_element(By.ID,"email").send_keys("sushil@gmail.com")
time.sleep(2)
driver.find_element(By.ID,"contact-number").send_keys("5515555551")
time.sleep(2)
driver.find_element(By.ID, "address").send_keys("76 hoboken st")
time.sleep(2)
driver.find_element(By.ID,"schedule-date").send_keys("10/01/2024")
time.sleep(2)
driver.find_element(By.ID,"schedule-time").send_keys("05:06PM")
time.sleep(2)
submit=driver.find_element(By.XPATH,"/html/body/form/button")
time.sleep(2)
driver.execute_script("arguments[0].click()",submit)
time.sleep(2)
#Handling the alert
alert = driver.switch_to.alert
alert.accept()
time.sleep(2)

#About Us page
about=driver.find_element(By.LINK_TEXT, "About")
time.sleep(2)
driver.execute_script("arguments[0].click()",about)
time.sleep(2)
driver.find_element(By.TAG_NAME,value="body").send_keys(Keys.PAGE_DOWN)
time.sleep(2)
driver.find_element(By.TAG_NAME,value="body").send_keys(Keys.UP)
time.sleep(2)

#Services page
services = driver.find_element(By.LINK_TEXT, "Services")
time.sleep(2)
driver.execute_script("arguments[0].click()",services)
time.sleep(2)
driver.execute_script("window.scrollBy(0,1200)","")
#driver.find_element(By.TAG_NAME,value="body").send_keys(Keys.PAGE_DOWN)
time.sleep(2)
#driver.find_element(By.TAG_NAME,value="body").send_keys(Keys.UP)
driver.execute_script("window.scrollBy(1200,0)","")
time.sleep(2)

#Contact Us page
contact = driver.find_element(By.LINK_TEXT, "Contact")
time.sleep(2)
driver.execute_script("arguments[0].click()",contact)
time.sleep(2)
driver.find_element(By.TAG_NAME,value="body").send_keys(Keys.PAGE_DOWN)
time.sleep(2)
driver.find_element(By.TAG_NAME,value="body").send_keys(Keys.UP)
time.sleep(2)

#Uploading an image
imageuploader = driver.find_element(By.LINK_TEXT, "Image Uploader")
time.sleep(2)
driver.execute_script("arguments[0].click()",imageuploader)
time.sleep(2)
driver.find_element(By.ID,"image").send_keys("path for picture to be uploaded")
time.sleep(2)
driver.find_element(By.XPATH,"/html/body/form/button").click()
time.sleep(2)

#Let's Chat Page
chat = driver.find_element(By.LINK_TEXT, "Chat")
time.sleep(2)
driver.execute_script("arguments[0].click()",chat)
time.sleep(2)
driver.find_element(By.ID,"message-input").send_keys("queries")
time.sleep(2)
driver.find_element(By.ID,"send-button").click()
time.sleep(2)

#Closing the browser
driver.quit()
